# %% [markdown]
# # **`Strategic Insights for Diamond Price Segmentation: A Clustering Analysis Report`**
#
# **INTRODUCTION**
#  This project aims to identify distinct price segments within the diamond market by grouping diamonds with similar characteristics using clustering techniques. Understanding price segmentation can benefit diamond buyers and sellers by providing insights into factors that influence diamond pricing.
#
#  **OBJECTIVE**
#
# 1. Identify the number of distinct price segments in the diamond market.
# 2. Develop a preliminary diamond price prediction model based on cluster membership.
# 3. Provide actionable insights for diamond buyers and sellers based on the identified price segments.
#
# # **DATA DESCRIPTION**
#
# Data Source is Kaggle. This dataset comprises of approximately 727kb of data. Data Link: https://www.kaggle.com/datasets/utkarshx27/prices-of-over-50000-round-cut-diamonds?select=diamonds.csv
#
#
# Dataset consists of 53940 rows and 11 columns. The characteristics of the index is:
#
# 1. Price of the diamond in US dollars (range: $326 - $18,823)
#
# 2. Carat: Weight of the diamond (range: 0.2 - 5.01 carats)
#
# 3. Cut: Quality of the cut (categories: Fair, Good, Very Good, Premium, Ideal)
#
# 4. Color: Diamond color, ranging from D (best) to J (worst)
#
# 5. Clarity: Measurement of diamond clarity (categories: I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#
# 6. x, y, z: Length, width, and depth of the diamond in millimeters (individual ranges provided in your description)
#
# 7. depth: Total depth percentage (calculated using x, y, and z)
#
# 8. table: Width of the top of the diamond relative to its widest point (range: 43% - 95%)
#
# **SET UP**
#
# The setup for this project involves loading necessary libraries and extensions to facilitate data analysis and preprocessing. Below is an overview of the setup process:
#
# *IPython Extensions*
#
# 1. autotime: Measures the execution time of code blocks automatically.
#
# 2. memory_profiler: Enables memory profiling to monitor memory usage during execution.
#
# *Libraries*
#
# 1. pandas: A powerful data manipulation library for loading, manipulating, and analyzing data.
# 2. numpy: A fundamental package for scientific computing with Python, used for numerical operations.
# 3. matplotlib.pyplot and seaborn: Visualization libraries for creating plots and graphs.
# 4. scipy.cluster.hierarchy: Library for hierarchical clustering algorithms.
# 5. sklearn.cluster.AgglomerativeClustering and sklearn.cluster.KMeans: Classes for performing agglomerative and KMeans clustering, respectively.
# 6. sklearn.metrics.silhouette_score and sklearn.metrics.davies_bouldin_score: Functions for evaluating clustering performance using silhouette score and Davies-Bouldin Index.
# 7. plotly.graph_objects: Library for creating interactive plots and graphs.
#
# *Preprocessing Libraries from scikit-learn*
#
# 1. LabelEncoder, OrdinalEncoder, OneHotEncoder: Used for encoding categorical variables.
# 2. SimpleImputer, KNNImputer: Used for imputing missing values in the dataset.
# 3. StandardScaler, MinMaxScaler, RobustScaler: Used for scaling numerical features.
# 4. train_test_split: Used for splitting the dataset into training and testing subsets.
#
# *Memory Profiling*
#
# 1. %memit: Measures the current memory usage.
#
# *There were no mising values in the dataset. The "Non-Null Count" column shows the number of non-null (non-missing) values for each feature.*
#
# ***
#
# # **DESCRIPTION STATISTICS**
#
# **DATA CLASSIFICATION**
#
# **_CATEGORICAL COLUMNS_**:
#
# 1. Cut: Quality of the cut
#
# Categories: Fair, Good, Very Good, Premium, Ideal;
# Represents the quality of the cut, indicating how well the diamond has been shaped.
#
# 2. Color: Diamond color
#
# Categories: D (best) to J (worst); Specifies the color of the diamond on a scale from D (colorless) to J (near colorless).
#
# 3. clarity: Measurement of clarity
# Categories: I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best); Reflects the clarity of the diamond, ranging from Included (I1) to Internally Flawless (IF).
#
# **_NON-CATEGORICAL COLUMNS (Continuous):_**
#
# 1. Price: Price of the diamond; Represents the price of the diamond in US dollars.
#
# 2. Carat: Weight of the diamond; Denotes the weight of the diamond, providing insight into its size.
#
# 3. x, y, z: Dimensions of the diamond; Represents the length, width, and depth of the diamond in millimeters.
#
# 4. Depth: Total depth percentage; Calculated as the total depth percentage, providing information about the depth relative to the dimensions.
#
# 5. Table: Width of the top of the diamond; Indicates the width of the top of the diamond relative to the widest point.
#
#
# **BOXPLOTS TO IDENTIFY OUTLIERS**
#
#  1. Box Plot for 'carat':
# Interpretation:
# The box plot for 'carat' shows the distribution of diamond weights.
# The box represents the interquartile range (IQR) where the central 50% of the data lies.
# The median line inside the box indicates the middle value of the 'carat' distribution.
# The whiskers extend to show the spread of the majority of the data, and any points beyond the whiskers may be considered outliers.
#
#  2. Box Plot for 'depth':
# Interpretation:
# The 'depth' box plot displays the distribution of total depth percentages for diamonds.
# The box represents the IQR, indicating where the central 50% of depth values lie.
# The position of the median line provides insights into the central tendency of the 'depth' data.
# Outliers, if present, can be identified as points beyond the whiskers.
#  3. Box Plot for 'table':
# Interpretation:
# The box plot for 'table' illustrates the distribution of width of the top of diamonds relative to the widest point.
# Similar to other box plots, the box represents the IQR, and the median line shows the central tendency.
# Whiskers indicate the spread of the majority of 'table' values, with potential outliers shown as individual points.
#  4. Box Plot for 'price':
# Interpretation:
# The box plot for 'price' reveals the distribution of diamond prices.
# The box represents the IQR of prices, and the median line indicates the central value.
# Whiskers show the spread of prices, and any points beyond the whiskers are potential outliers.
#  5. Box Plot for 'x', 'y', 'z':
# Interpretation:
# These box plots display the distribution of dimensions (length, width, depth) for diamonds.
# Each box represents the IQR of the respective dimension, and the median line indicates the central value.
# Whiskers show the spread of the majority of data for each dimension.
#
# This helped in interpreting that there are some outliers in every category.
#
# ****
#
# # **ANALYSIS OF DATA**
#
# **1. Data Pre-Processing**
#
# The data processing phase in this project involves several critical steps to prepare the dataset for analysis and modeling. Initially, missing data within the dataset is meticulously addressed through thorough examination at both the variable and record levels. This is achieved using techniques such as SimpleImputer or KNNImputer from the scikit-learn library, ensuring robustness in handling missing values. Subsequently, categorical variables like 'cut', 'color', and 'clarity' undergo numerical encoding utilizing the OrdinalEncoder from scikit-learn, facilitating their integration into the analysis pipeline. The encoded categorical variables are then stored separately for subsequent analysis. Moreover, non-categorical variables undergo rescaling using methods such as RobustScaler from scikit-learn, effectively mitigating the impact of outliers and ensuring uniformity in scale across features. The dataset is further bifurcated into training and testing subsets using the train_test_split function from scikit-learn, which is pivotal for model evaluation and validation. Following this, clustering algorithms such as K-Means and Agglomerative Clustering are employed to segment the data into meaningful clusters. Evaluation metrics such as silhouette score and Davies-Bouldin score are calculated to assess the quality of clustering results and determine the optimal number of clusters. Additionally, visualizations such as scatter plots are utilized to depict the clusters generated by the clustering algorithms, providing insights into the underlying patterns in the data. Finally, memory profiling is conducted using the %memit command to monitor the memory usage during the data processing phase, ensuring efficiency and resource optimization throughout the process. These meticulous data processing steps are essential for ensuring the quality and reliability of subsequent analysis and modeling tasks.
#
# **2. Data Bifurcation:**
#
# In the data bifurcation phase of the project, the dataset is split into distinct subsets for training and testing purposes, facilitating model evaluation and validation. This crucial step ensures that the model's performance can be accurately assessed on unseen data, thereby gauging its generalization capabilities. Leveraging the train_test_split function from the scikit-learn library, the dataset is randomly partitioned into two subsets: a training dataset and a testing dataset. Typically, a certain percentage of the data is allocated to the training subset, while the remainder is reserved for testing. This split allows for the model to learn patterns and relationships from the training data, which can then be assessed on the independent testing data to gauge its predictive performance. By bifurcating the dataset in this manner, the project ensures robustness in evaluating the model's efficacy and enables informed decision-making regarding its deployment and potential impact. Furthermore, the utilization of train_test_split ensures reproducibility and consistency in the evaluation process, laying the foundation for reliable and trustworthy model assessment. Overall, data bifurcation plays a pivotal role in the project's workflow, enabling rigorous evaluation and validation of the developed models and facilitating informed decision-making in subsequent stages of the project lifecycle.
#
# **3. Data Encoding:**
#
# In the data encoding phase of the project, categorical variables within the dataset are transformed into numerical representations to facilitate their integration into the analysis pipeline. This transformation is accomplished using techniques such as OrdinalEncoder and OneHotEncoder from the scikit-learn library, as implemented in the provided codes.
#
# Firstly, the categorical variables 'cut', 'color', and 'clarity' are identified and isolated from the dataset. These variables represent qualitative attributes such as the quality of the diamond cut, the color grade of the diamond, and the clarity rating of the diamond, respectively.
#
# Next, the OrdinalEncoder is applied to these categorical variables to encode them into numerical labels. This encoder assigns a unique integer value to each category within each variable, preserving the ordinal relationship between categories where applicable. For instance, in the 'cut' variable, categories such as 'Fair', 'Good', 'Very Good', 'Premium', and 'Ideal' are encoded with integer labels ranging from 0 to 4, reflecting their respective positions in the ordinal scale of cut quality.
#
# Once encoded, the numerical representations of the categorical variables are stored in separate dataframes for further analysis. These encoded variables can now be seamlessly integrated with the numerical features of the dataset, enabling comprehensive exploration and modeling of the data.
#
# Data Encoding involves converting categorical data into a numerical format that can be used by machine learning algorithms. This step is essential because many machine learning models require numerical input, and encoding helps represent categorical information in a way that is compatible with these models.I applied data encoding to the categorical columns ('cut', 'color', 'clarity') using Scikit Learn's Ordinal Encoder. This transformation was necessary to represent categorical information as numerical values, enabling the inclusion of these features in machine learning models.
#
# Overall, the data encoding process enhances the versatility and utility of the dataset by converting qualitative attributes into numerical representations, thereby enabling the application of a wide range of analytical techniques and machine learning algorithms. This facilitates a deeper understanding of the underlying patterns and relationships within the data, ultimately contributing to more informed decision-making and actionable insights.
#
# **4. Testing and Training Set:**
#
# In machine learning, a Testing Set and a Training Set are subsets of the dataset used for model development and evaluation. The Training Set is used to train the model, while the Testing Set is reserved for assessing the model's performance on unseen data.I split my preprocessed dataset (df_ppd) into training and testing sets using Scikit Learn's train_test_split function. This separation allowed me to train your machine learning models on one subset and evaluate their performance on another, providing an unbiased assessment of the model's generalization capabilities.
#
# **NOTE:**
# 1. Numeric encoding of categorical data was achieved through Label Encoding, mapping the original categories to numerical values.
# 2. Data transformation involved the identification and treatment of outliers, with box plots aiding in visualization.
# 3. The outlier list provides transparency regarding which observations were deemed outliers.
# 4. Data bifurcation into training and testing sets ensures a robust evaluation of machine learning models on unseen data.
#
# **Understanding the Elbow Curve**
#
# _WCSS:_ This metric represents the sum of the squared distances between each data point and its assigned cluster center (centroid) in a K-Means clustering solution. Lower WCSS generally indicates a better clustering fit, as data points are closer to their respective centroids.
# _Elbow Point:_ The elbow curve typically depicts a decrease in WCSS as the number of clusters increases. However, this decrease in WCSS becomes less significant after a certain point, forming an "elbow" shape in the curve. The number of clusters corresponding to this elbow is often considered the optimal value for K.
#
# Here the elbow seems to be around k=3 or k=4. This suggests that 3 or 4 clusters might be a suitable choice for segmenting the diamond prices in your dataset.
#
# X-axis: Values of K (number of clusters)
#
# Y-axis: Within-Cluster Sum of Squared Distances (inertia)
#
# There's a significant decrease in inertia as the number of clusters increases from 1 to 3 or 4. This indicates that these initial cluster separations are meaningful.
# The curve starts to flatten out around 3 or 4 clusters. Adding more clusters beyond this point may not provide a significant benefit in terms of reducing inertia, and might lead to overfitting the data.
#
# **Clustering Process:**
#
# Based on the analysis, the dataset was subjected to the K-Means clustering algorithm. Different values of k (number of clusters) were tested, including k=2, k=3, k=4, and k=5. The K-Means algorithm facilitated the grouping of data points into distinct clusters, identifying similarities and patterns within the data.
#
# _Silhouette Score (sscore) and Davies-Bouldin Score (dbscore)_: Silhouette Score and Davies-Bouldin Score were calculated for each value of k (2, 3, 4, and 5). The Silhouette Score measures how close each data point in one cluster is to the points in the neighboring clusters. Higher values indicate better-defined clusters.The Davies-Bouldin Score assesses the compactness and separation between clusters. Lower values suggest more distinct and well-separated clusters.
#
# ****
# # **OBSERVATION**
#
# Identified that for k=3, a high Silhouette Score was achieved, indicating that data points within each cluster are relatively close to each other and well-separated from points in other clusters. The Davies-Bouldin Score for k=3 was lower compared to other values of k, suggesting that the clusters are more separable and distinct from each other with lower intra-cluster variability and higher inter-cluster variability.
#
# Based on the analysis and model evaluation, it was determined that k=3 is an appropriate number of clusters for the dataset. The clusters exhibit high cohesion within themselves and clear separation from each other, making them meaningful segments for further exploration and analysis.
#
# Scatter plots are useful for visualizing the distribution of data points and identifying potential relationships between features. In the context of diamond price clustering, this scatter plot can reveal insights into how price is related to carat weight across different clusters.
#
# 1. Color-Coded Clusters: The different colors represent the clusters that the diamonds have been assigned to based on a clustering algorithm (like K-Means). Ideally, the colors should not be too similar, allowing for easy distinction between clusters.
#
# 2. Price vs. Carat Weight: By observing the distribution of data points within each color-coded cluster, you can see if there are any patterns between price and carat weight.
#
# In analyzing the clustering results, several key observations and insights have emerged, shedding light on the underlying market dynamics and segmentation within the diamond industry.
#
# Distinct Price Segment Characteristics: Through clustering analysis, we identified distinct price segments within the diamond market, each characterized by unique attributes and pricing dynamics. These segments exhibit variations in average price range, carat weight distribution, and other defining features, allowing for a nuanced understanding of market segmentation.
#
# Trends and Demand Patterns: Examination of market trends revealed intriguing patterns within each price segment over time. Some segments may experience fluctuations in demand or pricing trends, influenced by factors such as consumer preferences, economic conditions, and industry developments. By monitoring these trends, stakeholders can adapt their strategies to capitalize on emerging opportunities and mitigate risks.
#
# Customer Preferences and Buying Behavior: The clustering analysis provides insights into customer preferences and buying behavior across different price segments. For instance, customers in higher price segments may prioritize factors like diamond clarity and color, while those in lower segments may prioritize affordability or unique design features. Understanding these preferences allows for targeted marketing efforts and product differentiation strategies tailored to each segment's needs.
#
# Competitive Landscape Analysis: An assessment of the competitive landscape within each price segment helps stakeholders identify key competitors and market players. By understanding how competitors position themselves and differentiate their offerings within different segments, stakeholders can refine their own strategies to gain a competitive edge and capture market share effectively.
#
# Opportunities for Product Differentiation: By identifying preferences and trends within each price segment, stakeholders can uncover opportunities for product differentiation and innovation. Tailoring product offerings to meet the specific needs and preferences of each segment enhances customer satisfaction and strengthens brand loyalty, driving long-term growth and profitability.
#
# Strategic Pricing Recommendations: Drawing on insights from clustering analysis and market dynamics, strategic pricing recommendations can be formulated to optimize revenue and profitability across different segments. These recommendations may include pricing adjustments, promotional strategies, and bundling tactics aimed at maximizing value for customers while maintaining competitive positioning in the market.
#
# Future Growth Strategies: Looking ahead, identifying future growth opportunities within each price segment is essential for long-term success. Whether through geographic expansion, product diversification, or targeted marketing initiatives, outlining growth strategies tailored to each segment's unique characteristics enables stakeholders to capitalize on emerging market trends and drive sustainable growth.
#
# Incorporating these refined observations and insights into the report provides stakeholders with a comprehensive understanding of market segmentation and actionable strategies for navigating the complex landscape of the diamond industry. By leveraging these insights, stakeholders can make informed decisions to drive business growth and achieve competitive advantage in the marketplace.
#
# ****
# # **MANAGERIAL IMPLICATIONS**
#
# 1. **Segment-Specific Marketing Strategies**: Tailoring marketing efforts to target each identified price segment can enhance customer engagement and drive sales. By understanding the unique preferences and behaviors of customers within each segment, marketing messages can be customized to resonate with their needs and aspirations, increasing the effectiveness of promotional campaigns.
#
# 2. **Product Development and Innovation**: Insights from clustering analysis can inform product development initiatives aimed at meeting the evolving needs of customers across different price segments. By identifying unmet needs and emerging trends within each segment, companies can innovate and introduce new products or features that resonate with target customers, driving competitiveness and market share.
#
# 3. **Pricing Optimization**: Leveraging clustering results, companies can optimize pricing strategies to maximize profitability while maintaining competitiveness. Differentiated pricing strategies tailored to each segment's willingness to pay and perceived value can help capture consumer surplus and improve overall revenue performance.
#
# 4. **Supply Chain Management**: Understanding demand patterns and preferences within each price segment can guide inventory management and supply chain optimization efforts. By aligning inventory levels and production schedules with segment-specific demand forecasts, companies can minimize stockouts, reduce excess inventory costs, and improve overall operational efficiency.
#
# 5. **Customer Experience Enhancement**: Personalizing the customer experience based on segment-specific preferences can drive customer satisfaction and loyalty. From customized product recommendations to tailored service offerings, companies can create memorable experiences that resonate with customers and foster long-term relationships, ultimately driving repeat business and word-of-mouth referrals.
#
# 6. **Market Expansion Opportunities**: Identifying growth opportunities in underserved or emerging segments can guide strategic expansion efforts. By analyzing market dynamics and competitive landscapes within each segment, companies can prioritize investment in high-potential markets and channels, accelerating growth and market penetration.
#
# 7. **Risk Mitigation and Contingency Planning**: Anticipating market shifts and potential disruptions within each segment enables companies to proactively mitigate risks and develop contingency plans. By monitoring external factors such as economic conditions, regulatory changes, and competitive threats, companies can adapt their strategies and operations to mitigate risks and capitalize on opportunities effectively.
#
# 8. **Data-Driven Decision Making**: Embracing a data-driven approach to decision-making empowers companies to leverage insights from clustering analysis and other analytical techniques to inform strategic initiatives. By institutionalizing a culture of data-driven decision-making, companies can foster agility, innovation, and resilience in an increasingly dynamic and competitive marketplace.
#
# By considering these managerial implications and incorporating them into strategic planning and decision-making processes, companies can unlock value, drive sustainable growth, and achieve competitive advantage in the diamond market and beyond.

# %%
# Required Libraries
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation

# %%
# Display All Columns of Dataset
pd.set_option('display.max_columns', None)

# %%
# Read the uploaded file into a DataFrame
df = pd.read_csv("/content/diamonds.csv")

# Display the DataFrame
print(df)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
# categorical and non categorical:
df_cat=df[['cut', 'color', 'clarity']]
df_noncat=df[['carat','depth', 'table', 'price', 'x', 'y','z']]

# %%
for i in df_cat:
  count=pd.concat([df_cat[i].value_counts(),df_cat[i].value_counts(normalize=True).mul(100).round(1)],axis=1,keys=('count','percentage')).reset_index()
  print(count)
# Out:
#        index  count  percentage
# 0      Ideal  21551        40.0
# 1    Premium  13791        25.6
# 2  Very Good  12082        22.4
# 3       Good   4906         9.1
# 4       Fair   1610         3.0
#   index  count  percentage
# 0     G  11292        20.9
# 1     E   9797        18.2
# 2     F   9542        17.7
# 3     H   8304        15.4
# 4     D   6775        12.6
# 5     I   5422        10.1
# 6     J   2808         5.2
#   index  count  percentage
# 0   SI1  13065        24.2
# 1   VS2  12258        22.7
# 2   SI2   9194        17.0
# 3   VS1   8171        15.1
# 4  VVS2   5066         9.4
# 5  VVS1   3655         6.8
# 6    IF   1790         3.3
# 7    I1    741         1.4

# %%
import matplotlib.pyplot as plt

# Iterate over each categorical variable
for column in df_cat.columns:
    # Calculate value counts for the current column
    value_counts = df_cat[column].value_counts()

    # Create a new figure and axis for each pie chart
    plt.figure(figsize=(3,3))  # Adjust the figure size as needed
    plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=140)
    plt.title(f"Pie Chart of {column}")
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

    # Show the pie chart
    plt.show()

# %%
df_noncat.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
for i in df_noncat:
    # Calculate the standard deviation of each column
    std1 = round(np.std(df_noncat[i]), 2)
    print(f"Standard deviation of'{i}': {std1}")
# Out:
# Standard deviation of'carat': 0.47
# Standard deviation of'depth': 1.43
# Standard deviation of'table': 2.23
# Standard deviation of'price': 3989.4
# Standard deviation of'x': 1.12
# Standard deviation of'y': 1.14
# Standard deviation of'z': 0.71

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sps

cols=df_noncat.columns
# Initialize an empty DataFrame to store p-values
p_values_df = pd.DataFrame(index=cols, columns=cols)

# Iterate over each pair of columns
for col1 in cols:
    for col2 in cols:
        # Skip if the columns are the same or if any of them is non-numeric
        if col1 == col2 or not (df_noncat[col1].dtype == 'float64' and df_noncat[col2].dtype == 'float64'):
            continue

        # Drop rows with NaN values in both columns
        filtered_df = df_noncat[[col1, col2]].dropna()

        # Perform Pearson correlation test
        _, p_value = sps.pearsonr(filtered_df[col1], filtered_df[col2])

        # Store the p-value in the DataFrame
        p_values_df.loc[col1, col2] = p_value

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(p_values_df.astype(float), annot=True, cmap='coolwarm', fmt=".3f", cbar_kws={'label': 'p-value'})
plt.title('Heatmap of Pearson Correlation P-values')
plt.xlabel('Variable')
plt.ylabel('Variable')
plt.show()

# %%
# 1.1. Missing Data Information
# -----------------------------

# Dataset Used : df

df.info() # Dataframe Information (Provide Information on Missing Data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
# Out:
# 0        0
# 35977    0
# 35953    0
# 35954    0
# 35955    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
# 2.1. Numeric Encoding of Categorical Data [Nominal & Ordinal]
# -------------------------------------------------------------

# %%
# Using Scikit Learn : Ordinal Encoder (Superior)
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat)
df_cat_code_oe = pd.DataFrame(oe_fit, columns=['cut_code', 'color_code','clarity_code']); df_cat_code_oe
df_cat_mdt_code_oe = df_cat_code_oe; df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
# Out:
#        cut_code  color_code  clarity_code
# 0           2.0         1.0           3.0
# 1           3.0         1.0           2.0
# 2           1.0         1.0           4.0
# 3           3.0         5.0           5.0
# 4           1.0         6.0           3.0
# ...         ...         ...           ...
# 53935       2.0         0.0           2.0
# 53936       1.0         0.0           2.0
# 53937       4.0         0.0           2.0
# 53938       3.0         4.0           3.0
# 53939       2.0         0.0           3.0
#
# [53940 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
non_categorical_columns = ['carat', 'depth', 'table', 'price', 'x', 'y', 'z']

# Create a box plot for each non-categorical column
for column in non_categorical_columns:
    plt.figure(figsize=(4,2))
    sns.boxplot(x=df[column])
    plt.title(f'Box plot for {column}')
    plt.show()

# %%
# 3.2.1. Normalization : Min-Max Scaling
df_noncat_mdt=df_noncat.copy()
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat_mdt)
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=df_noncat_mdt.columns+'_mn'); df_noncat_minmax_norm
df_noncat_mdt_mmn = pd.merge(df_noncat_mdt, df_noncat_minmax_norm, left_index=True, right_index=True); df_noncat_mdt_mmn
# Out:
#        carat  depth  table  price     x     y     z  carat_mn  depth_mn  \
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43  0.006237  0.513889
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31  0.002079  0.466667
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31  0.006237  0.386111
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63  0.018711  0.538889
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75  0.022869  0.563889
# ...      ...    ...    ...    ...   ...   ...   ...       ...       ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50  0.108108  0.494444
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61  0.108108  0.558333
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56  0.103950  0.550000
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74  0.137214  0.500000
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64  0.114345  0.533333
#
#        table_mn  price_mn      x_mn      y_mn      z_mn
# ...

# %%
# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset
# Out:
#        cut_code  color_code  clarity_code
# 0           2.0         1.0           3.0
# 1           3.0         1.0           2.0
# 2           1.0         1.0           4.0
# 3           3.0         5.0           5.0
# 4           1.0         6.0           3.0
# ...         ...         ...           ...
# 53935       2.0         0.0           2.0
# 53936       1.0         0.0           2.0
# 53937       4.0         0.0           2.0
# 53938       3.0         4.0           3.0
# 53939       2.0         0.0           3.0
#
# [53940 rows x 3 columns]

# %%
# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_mdt_mmn.copy(); df_noncat_ppd
# Out:
#        carat  depth  table  price     x     y     z  carat_mn  depth_mn  \
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43  0.006237  0.513889
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31  0.002079  0.466667
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31  0.006237  0.386111
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63  0.018711  0.538889
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75  0.022869  0.563889
# ...      ...    ...    ...    ...   ...   ...   ...       ...       ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50  0.108108  0.494444
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61  0.108108  0.558333
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56  0.103950  0.550000
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74  0.137214  0.500000
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64  0.114345  0.533333
#
#        table_mn  price_mn      x_mn      y_mn      z_mn
# ...

# %%
# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd)
df_ppd
# Out:
#        cut_code  color_code  clarity_code  carat  depth  table  price     x  \
# 0           2.0         1.0           3.0   0.23   61.5   55.0    326  3.95
# 1           3.0         1.0           2.0   0.21   59.8   61.0    326  3.89
# 2           1.0         1.0           4.0   0.23   56.9   65.0    327  4.05
# 3           3.0         5.0           5.0   0.29   62.4   58.0    334  4.20
# 4           1.0         6.0           3.0   0.31   63.3   58.0    335  4.34
# ...         ...         ...           ...    ...    ...    ...    ...   ...
# 53935       2.0         0.0           2.0   0.72   60.8   57.0   2757  5.75
# 53936       1.0         0.0           2.0   0.72   63.1   55.0   2757  5.69
# 53937       4.0         0.0           2.0   0.70   62.8   60.0   2757  5.66
# 53938       3.0         4.0           3.0   0.86   61.0   58.0   2757  6.15
# 53939       2.0         0.0           3.0   0.75   62.2   55.0   2757  5.83
#
# ...

# %%
# 4. Data Bifurcation [Training & Testing Datasets]
# -------------------------------------------------

# Dataset Used : df_ppd

train_df, test_df = train_test_split(df_ppd, test_size=0.25, random_state=1234)
train_df # Training Dataset
test_df # Testing Dataset
# Out:
#        cut_code  color_code  clarity_code  carat  depth  table  price     x  \
# 18197       2.0         5.0           3.0   1.57   62.8   57.0   7385  7.39
# 34622       3.0         1.0           5.0   0.31   60.6   59.0    872  4.39
# 42495       4.0         2.0           2.0   0.51   61.7   55.0   1320  5.14
# 40139       0.0         3.0           0.0   0.70   64.6   59.0   1115  5.64
# 3872        4.0         4.0           3.0   0.90   62.3   61.0   3481  6.15
# ...         ...         ...           ...    ...    ...    ...    ...   ...
# 14687       3.0         5.0           5.0   1.25   62.2   57.0   5925  6.92
# 38933       2.0         1.0           4.0   0.40   62.2   55.0   1053  4.72
# 17849       1.0         0.0           5.0   1.00   63.9   56.0   7200  6.34
# 4431        4.0         3.0           2.0   0.90   63.4   54.0   3615  6.11
# 38977       2.0         1.0           5.0   0.43   61.6   54.0   1053  4.90
#
# ...

# %%
df_ppd.columns
# Out:
# Index(['cut_code', 'color_code', 'clarity_code', 'carat', 'depth', 'table',
#        'price', 'x', 'y', 'z', 'carat_mn', 'depth_mn', 'table_mn', 'price_mn',
#        'x_mn', 'y_mn', 'z_mn'],
#       dtype='object')

# %%
diamonds=df_ppd.copy()

# %% [markdown]
# # K-MEANS CLUSTERING

# %%
# 2.1.1. Determine Value of 'K' in K-Means using Elbow Curve & KMeans-Inertia
# ---------------------------------------------------------------------------
'''
KMeans-Inertia : Sum of Squared Distances of Samples to their closest Cluster Center (Centroid), Weighted by the Sample Weights (if provided)
'''
wcssd = [] # Within-Cluster-Sum-Squared-Distance
nr_clus = range(1,20) # Number of Clusters
for k in nr_clus:
    kmeans = kmclus(n_clusters=k, init='random', random_state=111)
    kmeans.fit(diamonds)
    wcssd.append(kmeans.inertia_)
plt.plot(nr_clus, wcssd, marker='x')
plt.xlabel('Values of K')
plt.ylabel('Within Cluster Sum Squared Distance')
plt.title('Elbow Curve for Optimal K')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
km_2cluster = kmclus(n_clusters=2, init='random', random_state=222)
km_2cluster_model = km_2cluster.fit_predict(diamonds); km_2cluster_model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
km_3cluster = kmclus(n_clusters=3, init='random', random_state=333)
km_3cluster_model = km_3cluster.fit_predict(diamonds); km_3cluster_model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([1, 1, 1, ..., 1, 1, 1], dtype=int32)

# %%
km_4cluster = kmclus(n_clusters=4, init='random', random_state=444)
km_4cluster_model = km_3cluster.fit_predict(diamonds); km_4cluster_model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([1, 1, 1, ..., 1, 1, 1], dtype=int32)

# %%
km_5cluster = kmclus(n_clusters=5, init='random', random_state=555)
km_5cluster_model = km_5cluster.fit_predict(diamonds); km_5cluster_model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([1, 1, 1, ..., 2, 2, 2], dtype=int32)

# %%
sscore_km_2cluster = sscore(df_ppd, km_2cluster_model)
dbscore_km_2cluster = dbscore(df_ppd, km_2cluster_model)
print("sscore for 2 clusters : ",sscore_km_2cluster)
print("dbscore for 2 clusters : ",dbscore_km_2cluster)
# Out:
# sscore for 2 clusters :  0.7078807401817108
# dbscore for 2 clusters :  0.4967176054967178

# %%
sscore_km_3cluster = sscore(df_ppd, km_3cluster_model)
dbscore_km_3cluster = dbscore(df_ppd, km_3cluster_model)
print("sscore for 3 clusters : ",sscore_km_3cluster)
print("dbscore for 3 clusters : ",dbscore_km_3cluster)
# Out:
# sscore for 3 clusters :  0.6602404917839305
# dbscore for 3 clusters :  0.48119049661265856

# %%
sscore_km_4cluster = sscore(df_ppd, km_4cluster_model)
dbscore_km_4cluster = dbscore(df_ppd, km_4cluster_model)
print("sscore for 4 clusters : ",sscore_km_4cluster)
print("dbscore for 4 clusters : ",dbscore_km_4cluster)
# Out:
# sscore for 4 clusters :  0.6602404917839305
# dbscore for 4 clusters :  0.48119049661265856

# %%
sscore_km_5cluster = sscore(df_ppd, km_5cluster_model)
dbscore_km_5cluster = dbscore(df_ppd, km_5cluster_model)
print("sscore for 5 clusters : ",sscore_km_5cluster)
print("dbscore for 5 clusters : ",dbscore_km_5cluster)
# Out:
# sscore for 5 clusters :  0.6172910548370318
# dbscore for 5 clusters :  0.5076946269257203

# %%
# 2.2. Create a KMeans Cluster Member Dataframe
# ---------------------------------------------

# Cluster Model Used : km_3cluster_model

diamonds_kmcluster =diamonds.copy()
diamonds_kmcluster['cluster_number'] = km_3cluster_model
diamonds_kmcluster
# Out:
#        cut_code  color_code  clarity_code  carat  depth  table  price     x  \
# 0           2.0         1.0           3.0   0.23   61.5   55.0    326  3.95
# 1           3.0         1.0           2.0   0.21   59.8   61.0    326  3.89
# 2           1.0         1.0           4.0   0.23   56.9   65.0    327  4.05
# 3           3.0         5.0           5.0   0.29   62.4   58.0    334  4.20
# 4           1.0         6.0           3.0   0.31   63.3   58.0    335  4.34
# ...         ...         ...           ...    ...    ...    ...    ...   ...
# 53935       2.0         0.0           2.0   0.72   60.8   57.0   2757  5.75
# 53936       1.0         0.0           2.0   0.72   63.1   55.0   2757  5.69
# 53937       4.0         0.0           2.0   0.70   62.8   60.0   2757  5.66
# 53938       3.0         4.0           3.0   0.86   61.0   58.0   2757  6.15
# 53939       2.0         0.0           3.0   0.75   62.2   55.0   2757  5.83
#
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Assuming you have a dataframe diamonds_kmcluster with columns carat_mn, depth_mn, table_mn, and cluster_number

# Extracting data
x = diamonds_kmcluster['carat_mn']
y = diamonds_kmcluster['depth_mn']
z = diamonds_kmcluster['table_mn']
cluster_numbers = diamonds_kmcluster['cluster_number']

# Create a 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
scatter = ax.scatter(x, y, z, c=cluster_numbers, cmap='viridis')

# Setting labels
ax.set_xlabel('Carat')
ax.set_ylabel('Depth')
ax.set_zlabel('Table')

# Adding a color bar
cbar = fig.colorbar(scatter)
cbar.set_label('Cluster Number')

# Show the plot
plt.show()

# %%
from scipy.stats import chi2_contingency

# Extracting categorical variables
cat_variables = ['cut_code', 'color_code', 'clarity_code']

# Perform Chi-square test for each categorical variable
chi2_results_cat = {}
for column in cat_variables:
    contingency_table = pd.crosstab(diamonds_kmcluster[column], km_3cluster_model)
    chi2, p_value, _, _ = chi2_contingency(contingency_table)
    chi2_results_cat[column] = {'Chi-square': chi2, 'P-value': p_value}

# Print Chi-square test results for categorical variables
for column, result in chi2_results_cat.items():
    print(f"for: {column}")
    print(f"Chi-square: {result['Chi-square']}")
    print(f"P-value: {result['P-value']}")
    print()
# Out:
# for: cut_code
# Chi-square: 1264.2626117531163
# P-value: 1.2450746402219855e-267
#
# for: color_code
# Chi-square: 2049.9526125826637
# P-value: 0.0
#
# for: clarity_code
# Chi-square: 3643.7010718846464
# P-value: 0.0

# %%
diamonds_cluster0= diamonds_kmcluster[diamonds_kmcluster['cluster_number'] == 0]
diamonds_cluster1= diamonds_kmcluster[diamonds_kmcluster['cluster_number'] == 1]
diamonds_cluster2= diamonds_kmcluster[diamonds_kmcluster['cluster_number'] == 2]

# %%
# ANOVA Using Scipy
#table_mn	price_mn	x_mn	y_mn	z_mn
anova_carat = sps.f_oneway(diamonds_cluster0.carat_mn,diamonds_cluster1.carat_mn,diamonds_cluster2.carat_mn) # ANOVA
anova_carat
# Out:
# F_onewayResult(statistic=93428.5314925494, pvalue=0.0)

# %%
# ANOVA Using Scipy
anova_table = sps.f_oneway(diamonds_cluster0.table_mn,diamonds_cluster1.table_mn,diamonds_cluster2.table_mn) # ANOVA
anova_table
# Out:
# F_onewayResult(statistic=615.3465503217375, pvalue=5.776271378993671e-265)

# %%
# ANOVA Using Scipy
anova_price = sps.f_oneway(diamonds_cluster0.price_mn,diamonds_cluster1.price_mn,diamonds_cluster2.price_mn) # ANOVA
anova_price
# Out:
# F_onewayResult(statistic=197057.19174487147, pvalue=0.0)

# %%
# ANOVA Using Scipy
anova_x = sps.f_oneway(diamonds_cluster0.x_mn,diamonds_cluster1.x_mn,diamonds_cluster2.x_mn) # ANOVA
anova_x
# Out:
# F_onewayResult(statistic=78434.9343099942, pvalue=0.0)

# %%
# ANOVA Using Scipy
anova_y = sps.f_oneway(diamonds_cluster0.y_mn,diamonds_cluster1.y_mn,diamonds_cluster2.y_mn) # ANOVA
anova_y
# Out:
# F_onewayResult(statistic=66690.68874745387, pvalue=0.0)

# %%
# ANOVA Using Scipy
anova_z = sps.f_oneway(diamonds_cluster0.z_mn,diamonds_cluster1.z_mn,diamonds_cluster2.z_mn) # ANOVA
anova_z
# Out:
# F_onewayResult(statistic=65645.95116138872, pvalue=0.0)

# %%
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler

# Assuming you have a DataFrame called 'df_ppd' with preprocessed data
# Use the features 'carat_rn' and 'depth_rn' for clustering
df_gauss = df_ppd[['carat_rn', 'depth_rn']].copy()

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_gauss)

# Initialize and fit the Gaussian Mixture Model
n_components = 3  # You can adjust the number of components/clusters
gmm = GaussianMixture(n_components=n_components, random_state=142)
gmm.fit(X_scaled)

# Get cluster labels
cluster_labels = gmm.predict(X_scaled)

# Add cluster labels to the DataFrame
df_gauss['Cluster'] = cluster_labels

# Display the DataFrame with cluster labels
df_gauss
# Out:
#        carat_rn  depth_rn  Cluster
# 0     -0.391667 -0.090909        0
# 1     -0.408333 -0.606061        0
# 2     -0.391667 -1.484848        2
# 3     -0.341667  0.181818        0
# 4     -0.325000  0.454545        0
# ...         ...       ...      ...
# 53935  0.016667 -0.303030        2
# 53936  0.016667  0.393939        2
# 53937  0.000000  0.303030        2
# 53938  0.133333 -0.242424        2
# 53939  0.041667  0.121212        2
#
# [53940 rows x 3 columns]

# %%
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score, davies_bouldin_score

# Assuming you have a DataFrame called 'df_ppd' with preprocessed data
# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_ppd)  # Using df_ppd instead of df_gauss

# Initialize and fit the Gaussian Mixture Model
n_components = 2  # You can adjust the number of components/clusters
gmm = GaussianMixture(n_components=n_components, random_state=142)
gmm.fit(X_scaled)

# Get cluster labels
cluster_labels = gmm.predict(X_scaled)

# Add cluster labels to the DataFrame
df_gauss = df_ppd.copy()  # Assuming df_ppd is your preprocessed data
df_gauss['Cluster'] = cluster_labels

# Display the DataFrame with cluster labels
print(df_gauss)

# Calculate silhouette score
silhouette_score_value = silhouette_score(X_scaled, cluster_labels)

# Calculate Davies-Bouldin score
davies_bouldin_score_value = davies_bouldin_score(X_scaled, cluster_labels)

print("Silhouette Score:", silhouette_score_value)
print("Davies-Bouldin Score:", davies_bouldin_score_value)
# Out:
#        cut_code  color_code  clarity_code  carat_rn  depth_rn  table_rn  \
# 0           2.0         1.0           3.0 -0.391667 -0.090909      -0.4
# 1           3.0         1.0           2.0 -0.408333 -0.606061       0.8
# 2           1.0         1.0           4.0 -0.391667 -1.484848       1.6
# 3           3.0         5.0           5.0 -0.341667  0.181818       0.2
# 4           1.0         6.0           3.0 -0.325000  0.454545       0.2
# ...         ...         ...           ...       ...       ...       ...
# 53935       2.0         0.0           2.0  0.016667 -0.303030       0.0
# 53936       1.0         0.0           2.0  0.016667  0.393939      -0.4
# 53937       4.0         0.0           2.0  0.000000  0.303030       0.6
# 53938       3.0         4.0           3.0  0.133333 -0.242424       0.2
# 53939       2.0         0.0           3.0  0.041667  0.121212      -0.4
#
#        price_rn      x_rn      y_rn      z_rn  Cluster
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a new figure and specify 3D projection
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Define colors and labels for clusters
cluster_labels = diamonds_kmcluster['cluster_number'].unique()
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

# Plot each cluster
for i, cluster_label in enumerate(cluster_labels):
    cluster_data = diamonds_kmcluster[diamonds_kmcluster['cluster_number'] == cluster_label]
    ax.scatter(cluster_data['carat_rn'], cluster_data['depth_rn'], cluster_data['cluster_number'], c=colors[i], label=f'Cluster {cluster_label}')

# Set labels and title
ax.set_xlabel('Carat (Normalized)')
ax.set_ylabel('Depth (Normalized)')
ax.set_zlabel('Cluster Number')
ax.set_title('Carat vs Depth Scatter Plot: K-Means Clusters')

# Add legend
ax.legend()

# Show grid
ax.grid(True)

# Show the plot
plt.show()
